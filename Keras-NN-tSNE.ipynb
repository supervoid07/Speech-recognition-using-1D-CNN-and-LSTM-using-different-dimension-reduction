# %%
import keras
import os
import librosa


import numpy as np
import pandas as pd

from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler


from keras.models import Sequential
from keras.utils import np_utils
from keras.utils import to_categorical
from keras.layers import Dense, Dropout, GaussianNoise, Conv1D
from keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\lenovo_pc\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def get_labels(path):
    labels = os.listdir(path)
    label_indices = np.arange(0, len(labels))    
    return labels, label_indices, to_categorical(label_indices)

# %%
def save_data_to_array(path, max_pad_len):
    labels, _, _ = get_labels(path)

    for label in labels:
        # Init mfcc vectors
        melspectrogram_vectors = []

        wavfiles = [path + '/' + label + '/' + wavfile for wavfile in os.listdir(path + '/' + label)]
        #wavfiles = librosa.util.find_files(db)
        #print(wavfiles)
        x=0
        for wavfile in wavfiles:
            name=label+'_'+str(x)
            melspectrogram = wav2melspectrogram(wavfile, name, max_pad_len=max_pad_len)            
            melspectrogram_vectors.append(melspectrogram)            
            x=x+1
        
        #computing PCA and saving
        
        np.save(label + '.npy', melspectrogram_vectors)
        #y=np.load(label + '.npy')
        #y = sklearn.preprocessing.scale(y)
        #y.mean()
        #model = sklearn.decomposition.PCA(n_components=2, whiten=True)
        #model.fit(y)
        #y = model.transform(y)
        #pd.DataFrame(y).to_csv(VALUE_PATH+'/'+label+'.csv')
        
        
sample_x=[]

def wav2melspectrogram(file_path, name, max_pad_len):
    wave, sr = librosa.load(file_path)
    x = librosa.feature.melspectrogram(wave, sr=sr)
    pad_width = max_pad_len - x.shape[1]
    x = np.pad(x, pad_width=((0, 0), (0, pad_width)), mode='constant')
    #here the dimensions are getting reduced 
    #through PCA decompostion
    x = reduce_dimension(x)
    pd.DataFrame(x).to_csv(VALUE_PATH+'/'+name+'.csv')
    return x

# %%
DATA_PATH = r'C:\Users\lenovo_pc\Desktop\CNN_SR\Dataset-v2'
VALUE_PATH = r'C:\Users\lenovo_pc\Desktop\CNN_SR\tSNE_matrix'

# %% [markdown]
# # t-Distributed Stochastic Neighbour Embedding (t-SNE)
# Like PCA, t-SNE is another dimensionality reduction technique, developed in part by the godfather of machine learning himself, Geoffrey Hinton. Quoting Wikipedia : It is a nonlinear dimensionality reduction technique well-suited for embedding high-dimensional data for visualization in a low-dimensional space of two or three dimensions. Specifically, it models each high-dimensional object by a two- or three-dimensional point in such a way that similar objects are modeled by nearby points and dissimilar objects are modeled by distant points with high probability.

# %% [markdown]
# labels, indices, _ = get_labels(DATA_PATH)
#
#  Getting first arrays
# T = np.load(labels[0] + '.npy')
#  Getting first element of first array
# X = T[127]
# print(X.shape)
#
#  Running t-SNE generating 3 dimensional data points
# print("Calculating TSNE")
# tsne = TSNE(n_components=3, perplexity=40, verbose=2, n_iter=500,early_exaggeration=1)
# tsne0 = tsne.fit_transform(X.T)
# tsne0 = StandardScaler().fit_transform(tsne0)
#
# print(tsne0.T.shape)

# %%
def reduce_dimension(X):
    tsne = TSNE(n_components=3, perplexity=40, verbose=2, n_iter=500,early_exaggeration=1)
    tsne0 = tsne.fit_transform(X.T)
    tsne0 = StandardScaler().fit_transform(tsne0)
    
    return tsne0.T

# %%
from sklearn.model_selection import train_test_split


def get_train_test(split_ratio=0.8, random_state=42):
    # Get available labels
    labels, indices, _ = get_labels(DATA_PATH)

    # Getting first arrays
    X = np.load(labels[0] + '.npy')
    # print(X.shape[0]) returns: 129
    y = np.zeros(X.shape[0])

    # Append all of the dataset into one single array, same goes for y
    for i, label in enumerate(labels[1:]):
        x = np.load(label + '.npy')
        X = np.vstack((X, x))
        #print(X.shape[0]) returns: 129+152=281
        #print(i) returns: 0: So all y values are 1 for Seven and 0 for Tin
        y = np.append(y, np.full(x.shape[0], fill_value= (i + 1)))

    assert X.shape[0] == len(y)

    return train_test_split(X, y, test_size= (1 - split_ratio), random_state=random_state, shuffle=True)

# %%
# Second dimension of the feature is dim2
feature_dim_2 = 22

# Save data to array file first
save_data_to_array(DATA_PATH,feature_dim_2)

# # Loading train set and test set
X_train, X_test, y_train, y_test = get_train_test()

# # Feature dimension
feature_dim_1 = 128
channel = 1
epochs = 50
batch_size = 100
verbose = 1
num_classes = 2


y_train_hot = to_categorical(y_train)
y_test_hot = to_categorical(y_test)
# Out:
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.018s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.057s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.187s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.031s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.029s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.030s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.026s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.021s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.007s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.002s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.057s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.045s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000001, gradient norm = 0.0000000 (50 iterations in 0.043s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000001, gradient norm = 0.0000000 (50 iterations in 0.033s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000001, gradient norm = 0.0000000 (50 iterations in 0.021s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000001, gradient norm = 0.0000000 (50 iterations in 0.026s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.007s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.021s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.026s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.021s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 6.613471
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = 0.4636723, gradient norm = 0.0003556 (50 iterations in 0.023s)
# [t-SNE] Iteration 100: error = 0.4347032, gradient norm = 0.0001437 (50 iterations in 0.018s)
# [t-SNE] Iteration 150: error = 0.4312088, gradient norm = 0.0000863 (50 iterations in 0.019s)
# [t-SNE] Iteration 200: error = 0.4286779, gradient norm = 0.0000591 (50 iterations in 0.027s)
# [t-SNE] Iteration 250: error = 0.4276786, gradient norm = 0.0000439 (50 iterations in 0.028s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.427679
# [t-SNE] Iteration 300: error = 0.4274711, gradient norm = 0.0000410 (50 iterations in 0.028s)
# [t-SNE] Iteration 350: error = 0.4269731, gradient norm = 0.0000347 (50 iterations in 0.037s)
# [t-SNE] Iteration 400: error = 0.4262606, gradient norm = 0.0000282 (50 iterations in 0.029s)
# [t-SNE] Iteration 450: error = 0.4253817, gradient norm = 0.0000228 (50 iterations in 0.029s)
# [t-SNE] Iteration 500: error = 0.4243535, gradient norm = 0.0000186 (50 iterations in 0.022s)
# [t-SNE] Error after 500 iterations: 0.424353
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = 0.0000001, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000001, gradient norm = 0.0000000 (50 iterations in 0.027s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.026s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.027s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 6.626064
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = 0.5328646, gradient norm = 0.0003277 (50 iterations in 0.025s)
# [t-SNE] Iteration 100: error = 0.5076625, gradient norm = 0.0001511 (50 iterations in 0.022s)
# [t-SNE] Iteration 150: error = 0.4987973, gradient norm = 0.0000903 (50 iterations in 0.021s)
# [t-SNE] Iteration 200: error = 0.4917898, gradient norm = 0.0000613 (50 iterations in 0.026s)
# [t-SNE] Iteration 250: error = 0.4865410, gradient norm = 0.0000451 (50 iterations in 0.023s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.486541
# [t-SNE] Iteration 300: error = 0.4853637, gradient norm = 0.0000420 (50 iterations in 0.030s)
# [t-SNE] Iteration 350: error = 0.4825920, gradient norm = 0.0000354 (50 iterations in 0.027s)
# [t-SNE] Iteration 400: error = 0.4793278, gradient norm = 0.0000285 (50 iterations in 0.029s)
# [t-SNE] Iteration 450: error = 0.4764552, gradient norm = 0.0000229 (50 iterations in 0.032s)
# [t-SNE] Iteration 500: error = 0.4742588, gradient norm = 0.0000186 (50 iterations in 0.027s)
# [t-SNE] Error after 500 iterations: 0.474259
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.026s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.031s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.034s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.043s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 26.387275
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = 0.4639921, gradient norm = 0.0005210 (50 iterations in 0.023s)
# [t-SNE] Iteration 100: error = 0.4252093, gradient norm = 0.0001760 (50 iterations in 0.026s)
# [t-SNE] Iteration 150: error = 0.4166977, gradient norm = 0.0000958 (50 iterations in 0.019s)
# [t-SNE] Iteration 200: error = 0.4130935, gradient norm = 0.0000628 (50 iterations in 0.021s)
# [t-SNE] Iteration 250: error = 0.4140848, gradient norm = 0.0000464 (50 iterations in 0.021s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.414085
# [t-SNE] Iteration 300: error = 0.4125741, gradient norm = 0.0000428 (50 iterations in 0.023s)
# [t-SNE] Iteration 350: error = 0.4120657, gradient norm = 0.0000359 (50 iterations in 0.020s)
# [t-SNE] Iteration 400: error = 0.4115633, gradient norm = 0.0000288 (50 iterations in 0.023s)
# [t-SNE] Iteration 450: error = 0.4124615, gradient norm = 0.0000231 (50 iterations in 0.021s)
# [t-SNE] Iteration 500: error = 0.4108853, gradient norm = 0.0000187 (50 iterations in 0.018s)
# [t-SNE] Error after 500 iterations: 0.410885
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.029s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.036s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.044s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.046s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.037s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.068s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.006s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.046s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.034s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 6.622767
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = 0.5850869, gradient norm = 0.0003559 (50 iterations in 0.031s)
# [t-SNE] Iteration 100: error = 0.4917735, gradient norm = 0.0001609 (50 iterations in 0.045s)
# [t-SNE] Iteration 150: error = 0.4687286, gradient norm = 0.0000893 (50 iterations in 0.030s)
# [t-SNE] Iteration 200: error = 0.4621111, gradient norm = 0.0000608 (50 iterations in 0.030s)
# [t-SNE] Iteration 250: error = 0.4590708, gradient norm = 0.0000454 (50 iterations in 0.035s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.459071
# [t-SNE] Iteration 300: error = 0.4584353, gradient norm = 0.0000423 (50 iterations in 0.026s)
# [t-SNE] Iteration 350: error = 0.4570353, gradient norm = 0.0000358 (50 iterations in 0.047s)
# [t-SNE] Iteration 400: error = 0.4558046, gradient norm = 0.0000292 (50 iterations in 0.057s)
# [t-SNE] Iteration 450: error = 0.4540573, gradient norm = 0.0000235 (50 iterations in 0.043s)
# [t-SNE] Iteration 500: error = 0.4524687, gradient norm = 0.0000191 (50 iterations in 0.039s)
# [t-SNE] Error after 500 iterations: 0.452469
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 9.357060
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 0.7642114, gradient norm = 0.0003722 (50 iterations in 0.040s)
# [t-SNE] Iteration 100: error = 0.4902211, gradient norm = 0.0001391 (50 iterations in 0.050s)
# [t-SNE] Iteration 150: error = 0.4798086, gradient norm = 0.0000840 (50 iterations in 0.026s)
# [t-SNE] Iteration 200: error = 0.4761106, gradient norm = 0.0000583 (50 iterations in 0.021s)
# [t-SNE] Iteration 250: error = 0.4744317, gradient norm = 0.0000436 (50 iterations in 0.025s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.474432
# [t-SNE] Iteration 300: error = 0.4740520, gradient norm = 0.0000407 (50 iterations in 0.022s)
# [t-SNE] Iteration 350: error = 0.4733793, gradient norm = 0.0000345 (50 iterations in 0.020s)
# [t-SNE] Iteration 400: error = 0.4727680, gradient norm = 0.0000280 (50 iterations in 0.018s)
# [t-SNE] Iteration 450: error = 0.4723007, gradient norm = 0.0000227 (50 iterations in 0.028s)
# [t-SNE] Iteration 500: error = 0.4719993, gradient norm = 0.0000185 (50 iterations in 0.030s)
# [t-SNE] Error after 500 iterations: 0.471999
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.021s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.021s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.002s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.033s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.026s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.030s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.029s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.029s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.026s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.029s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.027s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.030s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.031s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.030s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = 0.0000001, gradient norm = 0.0000000 (50 iterations in 0.031s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000001, gradient norm = 0.0000000 (50 iterations in 0.030s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.034s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.037s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.030s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.006s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.030s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.021s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.006s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.043s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.029s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = 0.0000001, gradient norm = 0.0000000 (50 iterations in 0.033s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000001, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.034s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.027s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.019s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.021s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.027s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.027s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.021s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.034s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# ...
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.045s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 105.947040
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = 0.6237115, gradient norm = 0.0004533 (50 iterations in 0.029s)
# [t-SNE] Iteration 100: error = 0.5882089, gradient norm = 0.0001722 (50 iterations in 0.022s)
# [t-SNE] Iteration 150: error = 0.5799881, gradient norm = 0.0000974 (50 iterations in 0.027s)
# [t-SNE] Iteration 200: error = 0.5759767, gradient norm = 0.0000652 (50 iterations in 0.031s)
# [t-SNE] Iteration 250: error = 0.5731804, gradient norm = 0.0000478 (50 iterations in 0.025s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.573180
# [t-SNE] Iteration 300: error = 0.5725573, gradient norm = 0.0000444 (50 iterations in 0.025s)
# [t-SNE] Iteration 350: error = 0.5709717, gradient norm = 0.0000374 (50 iterations in 0.020s)
# [t-SNE] Iteration 400: error = 0.5688377, gradient norm = 0.0000300 (50 iterations in 0.020s)
# [t-SNE] Iteration 450: error = 0.5664652, gradient norm = 0.0000241 (50 iterations in 0.018s)
# [t-SNE] Iteration 500: error = 0.5639651, gradient norm = 0.0000196 (50 iterations in 0.020s)
# [t-SNE] Error after 500 iterations: 0.563965
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.026s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.026s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.026s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.019s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.020s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.026s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 0.000000
# [t-SNE] Iteration 100: error = 0.0000000, gradient norm = 0.0000000 (50 iterations in 0.032s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: 0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.024s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.018s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.027s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.007s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.043s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.052s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.022s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.019s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.021s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000001, gradient norm = 0.0000000 (50 iterations in 0.021s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.023s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.001s...
# [t-SNE] Computed neighbors for 22 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.019s)
# [t-SNE] Iteration 50: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 50 iterations with early exaggeration: -0.000000
# [t-SNE] Iteration 100: error = -0.0000000, gradient norm = 0.0000000 (50 iterations in 0.025s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] Error after 100 iterations: -0.000000
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 13.152038
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 0.5294660, gradient norm = 0.0004736 (50 iterations in 0.026s)
# [t-SNE] Iteration 100: error = 0.4683577, gradient norm = 0.0001692 (50 iterations in 0.022s)
# [t-SNE] Iteration 150: error = 0.4569418, gradient norm = 0.0000978 (50 iterations in 0.021s)
# [t-SNE] Iteration 200: error = 0.4518207, gradient norm = 0.0000652 (50 iterations in 0.018s)
# [t-SNE] Iteration 250: error = 0.4488054, gradient norm = 0.0000477 (50 iterations in 0.019s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.448805
# [t-SNE] Iteration 300: error = 0.4482040, gradient norm = 0.0000443 (50 iterations in 0.022s)
# [t-SNE] Iteration 350: error = 0.4468369, gradient norm = 0.0000370 (50 iterations in 0.031s)
# [t-SNE] Iteration 400: error = 0.4453386, gradient norm = 0.0000296 (50 iterations in 0.025s)
# [t-SNE] Iteration 450: error = 0.4441310, gradient norm = 0.0000236 (50 iterations in 0.022s)
# [t-SNE] Iteration 500: error = 0.4432761, gradient norm = 0.0000192 (50 iterations in 0.027s)
# [t-SNE] Error after 500 iterations: 0.443276
# [t-SNE] Computing 21 nearest neighbors...
# [t-SNE] Indexed 22 samples in 0.000s...
# [t-SNE] Computed neighbors for 22 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 22 / 22
# [t-SNE] Mean sigma: 13.232979
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = 0.6615699, gradient norm = 0.0004188 (50 iterations in 0.028s)
# [t-SNE] Iteration 100: error = 0.5178118, gradient norm = 0.0001380 (50 iterations in 0.029s)
# [t-SNE] Iteration 150: error = 0.4976320, gradient norm = 0.0000829 (50 iterations in 0.023s)
# [t-SNE] Iteration 200: error = 0.4925208, gradient norm = 0.0000593 (50 iterations in 0.022s)
# [t-SNE] Iteration 250: error = 0.4897419, gradient norm = 0.0000450 (50 iterations in 0.019s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 0.489742
# [t-SNE] Iteration 300: error = 0.4891673, gradient norm = 0.0000421 (50 iterations in 0.024s)
# [t-SNE] Iteration 350: error = 0.4877330, gradient norm = 0.0000358 (50 iterations in 0.027s)
# [t-SNE] Iteration 400: error = 0.4856274, gradient norm = 0.0000292 (50 iterations in 0.024s)
# [t-SNE] Iteration 450: error = 0.4830100, gradient norm = 0.0000237 (50 iterations in 0.018s)
# [t-SNE] Iteration 500: error = 0.4802959, gradient norm = 0.0000193 (50 iterations in 0.020s)
# [t-SNE] Error after 500 iterations: 0.480296

# %%
#X_train = np.array(x_train)
print(X_train.shape)
print(X_test.shape)
# Out:
# (224, 3, 22)
# (57, 3, 22)

# %% [markdown]
# # *********++++++*********++++++*********++++++*********++++++

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D

# %%
seq_length = 128

model = Sequential()
model.add(Conv1D(64, 3, activation='relu', input_shape=(3,22)))
model.add(Conv1D(64, 1, activation='relu'))
model.add(Conv1D(64, 1, activation='relu'))
model.add(Conv1D(64, 1, activation='relu'))
model.add(MaxPooling1D(1))
model.add(Conv1D(128, 1, activation='relu'))
model.add(Conv1D(128, 1, activation='relu'))
model.add(Conv1D(128, 1, activation='relu'))
model.add(MaxPooling1D(1))
model.add(Conv1D(256, 1, activation='relu'))
model.add(Conv1D(256, 1, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train_hot, batch_size=7, epochs=10, validation_data=(X_test, y_test_hot))
# Out:
# Train on 224 samples, validate on 57 samples
# Epoch 1/10
# 224/224 [==============================] - 1s 6ms/step - loss: 0.6961 - acc: 0.4598 - val_loss: 0.6945 - val_acc: 0.4825
# Epoch 2/10
# 224/224 [==============================] - 0s 849us/step - loss: 0.6943 - acc: 0.5022 - val_loss: 0.6941 - val_acc: 0.5000
# Epoch 3/10
# 224/224 [==============================] - 0s 862us/step - loss: 0.6930 - acc: 0.5089 - val_loss: 0.6939 - val_acc: 0.5000
# Epoch 4/10
# 224/224 [==============================] - 0s 867us/step - loss: 0.6918 - acc: 0.5246 - val_loss: 0.6938 - val_acc: 0.4912
# Epoch 5/10
# 224/224 [==============================] - 0s 889us/step - loss: 0.6904 - acc: 0.5268 - val_loss: 0.6937 - val_acc: 0.5088
# Epoch 6/10
# 224/224 [==============================] - 0s 844us/step - loss: 0.6886 - acc: 0.5379 - val_loss: 0.6937 - val_acc: 0.5175
# Epoch 7/10
# 224/224 [==============================] - 0s 858us/step - loss: 0.6893 - acc: 0.5357 - val_loss: 0.6938 - val_acc: 0.5088
# Epoch 8/10
# 224/224 [==============================] - 0s 880us/step - loss: 0.6897 - acc: 0.5469 - val_loss: 0.6939 - val_acc: 0.5088
# Epoch 9/10
# 224/224 [==============================] - 0s 876us/step - loss: 0.6860 - acc: 0.5469 - val_loss: 0.6941 - val_acc: 0.5088
# Epoch 10/10
# 224/224 [==============================] - 0s 885us/step - loss: 0.6858 - acc: 0.5513 - val_loss: 0.6942 - val_acc: 0.5088

# %%
score = model.evaluate(X_train, y_train_hot, verbose=0) 
print ("model train data score       : ",round(score[1]*100) , "%")

score = model.evaluate(X_test, y_test_hot, verbose=0) 
print ("model test data score        : ",round(score[1]*100) , "%")
# Out:
# model train data score       :  55.0 %
# model test data score        :  51.0 %

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # *********++++++*********++++++*********++++++*********++++++

# %%
seq_length = 128

model = Sequential()
model.add(Conv1D(64, 3, activation='relu', input_shape=(3,22)))
model.add(Conv1D(64, 1, activation='relu'))
model.add(MaxPooling1D(1))
model.add(Conv1D(128, 1, activation='relu'))
model.add(Conv1D(128, 1, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
#model.fit(x_train, y_train, batch_size=7, epochs=10)

history = model.fit(X_train, y_train_hot, batch_size=batch_size, epochs=epochs, verbose=verbose, validation_data=(X_test, y_test_hot))
# Out:
# Train on 224 samples, validate on 57 samples
# Epoch 1/50
# 224/224 [==============================] - 1s 5ms/step - loss: 0.6949 - acc: 0.5179 - val_loss: 0.6974 - val_acc: 0.5000
# Epoch 2/50
# 224/224 [==============================] - 0s 85us/step - loss: 0.6712 - acc: 0.6362 - val_loss: 0.7056 - val_acc: 0.5000
# Epoch 3/50
# Epoch 47/50
# 224/224 [==============================] - 0s 98us/step - loss: 3.0843e-04 - acc: 1.0000 - val_loss: 3.5418 - val_acc: 0.4561
# Epoch 48/50
# 224/224 [==============================] - 0s 98us/step - loss: 2.5114e-04 - acc: 1.0000 - val_loss: 3.6205 - val_acc: 0.4649
# Epoch 49/50
# 224/224 [==============================] - 0s 112us/step - loss: 2.5894e-04 - acc: 1.0000 - val_loss: 3.6700 - val_acc: 0.4474
# Epoch 50/50
# 224/224 [==============================] - 0s 107us/step - loss: 1.3744e-04 - acc: 1.0000 - val_loss: 3.6779 - val_acc: 0.4386

# %%
score = model.evaluate(X_train, y_train_hot, verbose=0) 
print ("model train data score       : ",round(score[1]*100) , "%")

score = model.evaluate(X_test, y_test_hot, verbose=0) 
print ("model test data score        : ",round(score[1]*100) , "%")
# Out:
# model train data score       :  100.0 %
# model test data score        :  44.0 %

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # *********++++++*********++++++*********++++++*********++++++

# %% [markdown]
# # RNN+LSTM

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, LSTM
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint,TensorBoard,ProgbarLogger
from keras.utils import np_utils
from sklearn import metrics 
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
import itertools

# %%
print('Build LSTM RNN model ...')
model = Sequential()
model.add(LSTM(units=64, dropout=0.05, recurrent_dropout=0.20, return_sequences=True,input_shape = (3,22)))
model.add(LSTM(units=32, dropout=0.05, recurrent_dropout=0.20, return_sequences=False))
model.add(Dense(2, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='Adamax', metrics=['acc','mse', 'mae', 'mape', 'cosine'])
model.summary()
# Out:
# Build LSTM RNN model ...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 3, 64)             22272
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 34,754
# Trainable params: 34,754
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
# saved model checkpoint file
best_model_file="./best_model_trained.hdf5"
#train_model_file=file_path+"/checkpoints/weights.best_{epoch:02d}-{loss:.2f}.hdf5"
MAX_PATIENT=12
MAX_EPOCHS=50
MAX_BATCH=7

# callbacks
# removed EarlyStopping(patience=MAX_PATIENT)
callback=[ReduceLROnPlateau(patience=MAX_PATIENT, verbose=1),
          ModelCheckpoint(filepath=best_model_file, monitor='loss', verbose=1, save_best_only=True)]

print ("training started..... please wait.")
# training
history=model.fit(X_train, y_train_hot, 
                  batch_size=MAX_BATCH, 
                  epochs=MAX_EPOCHS,
                  verbose=0,
                  validation_data=(X_test, y_test_hot),
                  callbacks=callback) 

print ("training finised!")
# Out:
# training started..... please wait.
#
# Epoch 00001: loss improved from inf to 0.69887, saving model to ./best_model_trained.hdf5
#
# Epoch 00002: loss improved from 0.69887 to 0.68321, saving model to ./best_model_trained.hdf5
#
# Epoch 00003: loss improved from 0.68321 to 0.67525, saving model to ./best_model_trained.hdf5
#
# Epoch 00004: loss improved from 0.67525 to 0.66699, saving model to ./best_model_trained.hdf5
#
# Epoch 00005: loss improved from 0.66699 to 0.65727, saving model to ./best_model_trained.hdf5
#
# Epoch 00006: loss improved from 0.65727 to 0.64137, saving model to ./best_model_trained.hdf5
#
# Epoch 00007: loss improved from 0.64137 to 0.62858, saving model to ./best_model_trained.hdf5
#
# Epoch 00008: loss improved from 0.62858 to 0.61233, saving model to ./best_model_trained.hdf5
#
# Epoch 00009: loss improved from 0.61233 to 0.59386, saving model to ./best_model_trained.hdf5
#
# Epoch 00010: loss improved from 0.59386 to 0.57943, saving model to ./best_model_trained.hdf5
#
# Epoch 00011: loss improved from 0.57943 to 0.56971, saving model to ./best_model_trained.hdf5
#
# Epoch 00012: loss improved from 0.56971 to 0.54015, saving model to ./best_model_trained.hdf5
#
# Epoch 00013: loss improved from 0.54015 to 0.50922, saving model to ./best_model_trained.hdf5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00014: loss improved from 0.50922 to 0.47348, saving model to ./best_model_trained.hdf5
#
# Epoch 00015: loss improved from 0.47348 to 0.44511, saving model to ./best_model_trained.hdf5
#
# Epoch 00016: loss did not improve from 0.44511
#
# Epoch 00017: loss did not improve from 0.44511
#
# Epoch 00018: loss improved from 0.44511 to 0.42305, saving model to ./best_model_trained.hdf5
#
# Epoch 00019: loss did not improve from 0.42305
#
# Epoch 00020: loss did not improve from 0.42305
#
# Epoch 00021: loss did not improve from 0.42305
#
# Epoch 00022: loss improved from 0.42305 to 0.41888, saving model to ./best_model_trained.hdf5
#
# Epoch 00023: loss improved from 0.41888 to 0.41862, saving model to ./best_model_trained.hdf5
#
# Epoch 00024: loss improved from 0.41862 to 0.41236, saving model to ./best_model_trained.hdf5
#
# Epoch 00025: loss did not improve from 0.41236
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
#
# Epoch 00026: loss improved from 0.41236 to 0.40294, saving model to ./best_model_trained.hdf5
#
# Epoch 00027: loss improved from 0.40294 to 0.39235, saving model to ./best_model_trained.hdf5
#
# Epoch 00028: loss did not improve from 0.39235
#
# Epoch 00029: loss did not improve from 0.39235
#
# Epoch 00030: loss did not improve from 0.39235
#
# Epoch 00031: loss did not improve from 0.39235
#
# Epoch 00032: loss did not improve from 0.39235
#
# Epoch 00033: loss did not improve from 0.39235
#
# Epoch 00034: loss did not improve from 0.39235
#
# Epoch 00035: loss did not improve from 0.39235
#
# Epoch 00036: loss did not improve from 0.39235
#
# Epoch 00037: loss improved from 0.39235 to 0.38596, saving model to ./best_model_trained.hdf5
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 2.0000001313746906e-06.
#
# Epoch 00038: loss did not improve from 0.38596
#
# Epoch 00039: loss did not improve from 0.38596
#
# Epoch 00040: loss did not improve from 0.38596
#
# Epoch 00041: loss did not improve from 0.38596
#
# Epoch 00042: loss improved from 0.38596 to 0.38240, saving model to ./best_model_trained.hdf5
#
# Epoch 00043: loss did not improve from 0.38240
#
# Epoch 00044: loss did not improve from 0.38240
#
# Epoch 00045: loss improved from 0.38240 to 0.38023, saving model to ./best_model_trained.hdf5
#
# Epoch 00046: loss did not improve from 0.38023
#
# Epoch 00047: loss did not improve from 0.38023
#
# Epoch 00048: loss did not improve from 0.38023
#
# Epoch 00049: loss did not improve from 0.38023
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 2.000000222324161e-07.
#
# Epoch 00050: loss did not improve from 0.38023
# training finised!
# Wall time: 30.3 s

# %%
score = model.evaluate(X_train, y_train_hot, verbose=0) 
print ("model train data score       : ",round(score[1]*100) , "%")

score = model.evaluate(X_test, y_test_hot, verbose=0) 
print ("model test data score        : ",round(score[1]*100) , "%")
# Out:
# model train data score       :  88.0 %
# model test data score        :  49.0 %

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
